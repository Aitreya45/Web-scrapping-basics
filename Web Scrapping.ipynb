# %%
! pip install beautifulsoup4

# %%
! pip install requests

# %% [markdown]
# ##### Steps for web scrapping

# %% [markdown]
# * Document Load
# * Parsing
# * Extraction
# * Tranformation

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ## Scrapping CRICBUZZ Data

# %%
try:
    page = requests.get('https://www.cricbuzz.com/')

except exception as e:                                      #This is for what to do when exception is thrown
    error_type, error_obj, error_info = sys.exc_info()      #To get exception information
    print('Error for link:',url)                            #Print link that cause problem
    print(error_type, 'Line:',error_info.tb_lineno)         #print error info and line that threw exception

time.sleep(2)                                                #Time-out limit: This ensures that If we continuously send reqests then we don't getblocked
soup = BeautifulSoup(page.text, 'html.parser')
links = soup.find_all('div', attrs = {'class':'cb-nws-intr'}) # Division tag and class name of html text

# %% [markdown]
# * We should always use Try catch block incase our request is not accepted by website

# %%
page
# Out:
# <Response [200]>

# %%
print(links[0].text)
# Out:
# CSK CEO Kasi Viswanathan has said Raina will miss the tournament due to "personal reasons"

# %%
print(links[1].text)
# Out:
# Cricket Australia's standoff with one of its biggest broadcast partners has spilled into the media, highlighting the difficulties that the organisation faces in the COVID-19 world

# %%
soup.title
# Out:
# <title itemprop="name">Cricket Score, Schedule, Latest News, Stats &amp; Videos | Cricbuzz.com</title>

# %%
soup.title.string
# Out:
# 'Cricket Score, Schedule, Latest News, Stats & Videos | Cricbuzz.com'

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# One India player amongst those tested positive in Dubai; Chennai Super Kings' quarantine has been extended
#
#
# While England have picked a completely different squad to the one that played the Tests, Pakistan welcome back a few experienced players
#
#
# The bowlers have dominated this season so far, but how are the IPL recruits doing before they head to UAE?
#
#
# Afghanistan's interim chief was confident that CA would agree to ACB's request of hosting the Test as a day game instead of it being played under lights
#
#
# Cricket Australia has banned its players from using sweat from their head, face or neck - in addition to the saliva-ban - during their six-game limited-overs tour of UK
#
#
# How CSA go about deciding who is compensated and by how much promises to be difficult
#
#
# The saga, which started when Moroe was suspended in December, seems set to drag on in the courts
#
#
# ...

# %% [markdown]
# ## Scrapping Amazon Reviews

# %%
try:
    page = requests.get('https://www.amazon.in/Apple-iPhone-11-Pro-256GB/product-reviews/B07XVMJF2D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews')

except exception as e:                                      #This is for what to do when exception is thrown
    error_type, error_obj, error_info = sys.exc_info()      #To get exception information
    print('Error for link:',url)                            #Print link that cause problem
    print(error_type, 'Line:',error_info.tb_lineno)         #print error info and line that threw exception

time.sleep(2)                                                #Time-out limit: This ensures that If we continuously send reqests then we don't getblocked
soup = BeautifulSoup(page.text, 'html.parser')
links = soup.find_all('span', attrs = {'class':'a-size-base'}) # Division tag and class name of html text

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# 488 customer ratings
#
#
#
#
#             5 star
#
#
#
#
#
#
#
#               77%
#
#
#
#
#
#
#
#             4 star
#
#
#
#
#
#
#
#               11%
#
#
#
#
#
#
#
#             3 star
#
#
#
#
#
#
#
#               2%
#
#
#
#
#
#
#
#             2 star
#
#
#
#
#
#
#
#               1%
#
#
#
#
#
#
#
#             1 star
#
#
#
#
#
#
#
#               8%
#
#
#
#
#
#
#     byApple
#
#
#
# ›
#
#
# BEST PHONE in the SmartPhone Market..........Hands'Down
#
#
# Reviewed in India on 16 September 2019
#
#
# ...

# %% [markdown]
# ## Scrapping Images(WikiPedia)

# %%
from urllib.request import urlopen
import re

html = urlopen('https://en.wikipedia.org/wiki/Peter_Jeffrey_(RAAF_officer)')
bs = BeautifulSoup(html, 'html.parser')
images = bs.find_all('img', {'src':re.compile('.jpg')})
for image in images: 
    print(image['src']+'\n')
# Out:
# //upload.wikimedia.org/wikipedia/commons/thumb/a/af/NlaJeffrey1942-43.jpg/220px-NlaJeffrey1942-43.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/c/c5/008315JeffreyTurnbull1941.jpg/260px-008315JeffreyTurnbull1941.jpg
#
# //upload.wikimedia.org/wikipedia/commons/e/ea/021807CameronJeffrey1941.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/9/92/AC0072JeffreyTruscottKittyhawks1942.jpg/280px-AC0072JeffreyTruscottKittyhawks1942.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/2/26/VIC1689Jeffrey1945.jpg/280px-VIC1689Jeffrey1945.jpg

# %% [markdown]
# ## States and UTs of India

# %%
import urllib.request
wiki = "https://en.wikipedia.org/wiki/List_of_state_and_union_territory_capitals_in_India"
#Query the website and return the html to the variable 'page'
#For python 3 use urllib.request.urlopen(wiki)
page = urllib.request.urlopen(wiki) 

#Parse the html in the 'page' variable, and store it in Beautiful Soup format
soup = BeautifulSoup(page,features='html.parser')
print('\n\nPage Scrapped !!!\n\n')


print('\n\nTITLE OF THE PAGE\n\n')
print(soup.title.string)

print('\n\nALL THE URLs IN THE WEB PAGE\n\n')
# Out:
# Page Scrapped !!!
#
#
#
#
# TITLE OF THE PAGE
#
#
# List of state and union territory capitals in India - Wikipedia
#
#
# ALL THE URLs IN THE WEB PAGE

# %%
all_links = soup.find_all('a')

print('Total number of URLs present = ',len(all_links)) 

print('\n\nLast 5 URLs in the page are : \n')

if len(all_links) > 5 :
  
  last_5 = all_links[len(all_links)-5:]
  for url in last_5 :
    print(url.get('href'))
# Out:
# Total number of URLs present =  471
#
#
# Last 5 URLs in the page are :
#
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %%
all_tables=soup.find_all('table')

# %%
right_table=soup.find('table', class_='wikitable sortable plainrowheaders')
right_table

# %%
soup.find_all('table',class_ = 'wikitable sortable plainrowheaders')

# %%
#Generate lists
A=[]
B=[]
C=[]
D=[]
E=[]
F=[]
G=[]
for row in right_table.findAll("tr"):
    cells = row.findAll('td')
    states=row.findAll('th') #To store second column data
    if len(cells)==6: #Only extract table body not heading
        A.append(cells[0].find(text=True))
        B.append(states[0].find(text=True))
        C.append(cells[1].find(text=True))
        D.append(cells[2].find(text=True))
        E.append(cells[3].find(text=True))
        F.append(cells[4].find(text=True))
        G.append(cells[5].find(text=True))

# %%
df=pd.DataFrame(A,columns=['Number'])
df['State/UT']=B
df['Admin_Capital']=C
df['Legislative_Capital']=D
df['Judiciary_Capital']=E
df['Year_Capital']=F
df['Former_Capital']=G
df
# Out:
#    Number                                  State/UT       Admin_Capital  \
# 0     1\n               Andaman and Nicobar Islands          Port Blair
# 1     2\n                            Andhra Pradesh       Visakhapatnam
# 2     3\n                         Arunachal Pradesh            Itanagar
# 3     4\n                                     Assam              Dispur
# 4     5\n                                     Bihar               Patna
# 5     6\n                                Chandigarh          Chandigarh
# 6     7\n                              Chhattisgarh         Naya Raipur
# 7     8\n  Dadra and Nagar Haveli and Daman and Diu               Daman
# 8     9\n                                     Delhi           New Delhi
# 9    10\n                                       Goa              Panaji
# 10   11\n                                   Gujarat         Gandhinagar
# 11   12\n                                   Haryana          Chandigarh
# ...
